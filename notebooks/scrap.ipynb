# %%
import pandas as pd
from psai.game.translations import encode_human_to_vector_board
import numpy as np

# %%
a = np.zeros((4, 2))
a[0, 0] = 0
a[1, 0] = 1
a[2, 0] = 2
a[3, 0] = 3
a[0, 1] = 4
a[1, 1] = 5
a[2, 1] = 6
a[3, 1] = 7
a
# Out:
# array([[0., 4.],
#        [1., 5.],
#        [2., 6.],
#        [3., 7.]])

# %%
a.flatten()
# Out:
# array([0., 4., 1., 5., 2., 6., 3., 7.])
