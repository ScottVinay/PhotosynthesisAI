# %%
import pandas as pd
from psai.game.translations import encode_human_to_vector_board
import numpy as np
from dataclasses import fields, dataclass
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from psai.game.translations import encode_human_to_vector_board
#       3 import numpy as np
#       4 from dataclasses import fields, dataclass
#
# File ~/My Drive/Github/PhotosynthesisAI/src/psai/game/translations.py:6
#       1 """
#       2 This is for translating human-readable game states into vectors and vice-versa.
#       3 """
#       5 import numpy as np
# ----> 6 from psai.game.env import State, Cell
#       7 from psai.game.actions import Action
#       8 from psai.game.utils import cell_int_to_tuple, cell_tuple_to_int
#
# File ~/My Drive/Github/PhotosynthesisAI/src/psai/game/env.py:5
#       3 from typing import Iterable, Optional
#       4 from psai.agents.base import BaseAgent
# ----> 5 from psai.game.translations import decode_int_to_human_action
# ...

# %%
a = np.zeros((4, 2))
a[0, 0] = 0
a[1, 0] = 1
a[2, 0] = 2
a[3, 0] = 3
a[0, 1] = 4
a[1, 1] = 5
a[2, 1] = 6
a[3, 1] = 7
a
# Out:
# array([[0., 4.],
#        [1., 5.],
#        [2., 6.],
#        [3., 7.]])

# %%
a.flatten()
# Out:
# array([0., 4., 1., 5., 2., 6., 3., 7.])
