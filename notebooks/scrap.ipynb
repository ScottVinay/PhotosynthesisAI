# %%
def getprob(i, n):
    if i == 0:
        return 1
    else:
        return (n-1) / n * getprob(i - 1, n - 1)

1-getprob(4*3, 20)
# Out:
# 0.6000000000000001

# %%
class Parent:
    def __init__(self):
        self.x = 5

    def method(self, x):
        print(x + 1)
    
class Child(Parent):
    def __init__(self):
        super().__init__()
        self.y = 10

    def method(self, x):
        print(x + 2)
        super().method(x)

child = Child()
child.method(3)
# Out:
# 5
# 4

# %%
type(Child)
# Out:
# type
